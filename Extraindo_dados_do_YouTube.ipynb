# %% [markdown]
# <a href="https://colab.research.google.com/github/zeroaioficial/data_marketing/blob/main/Extraindo_dados_do_YouTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="10%" src="https://zeroai.com.br/wp-content/uploads/2021/09/cropped-cropped-logo_zero_preto.png">
#
# ##### **Discover | Projetos**
# *by [Hyan Dias](https://www.linkedin.com/in/hyan-dias/)*
#
#
# # **EXTRAINDO DADOS DO YOUTUBE**
# ### UTILIZANDO A API EM PYTHON
# ____
# <img alt="capa" width="70%" src="https://zeroai.com.br/wp-content/uploads/2022/10/CAPA.png">
#
# O [YouTube](https://www.youtube.com/) é uma plataforma de streaming que permite a criação e consumo de conteúdos em vídeos. Diferente de uma Netflix, os próprios usuários criam os conteúdos, e os mesmos são monetizados conforme o consumo de seus vídeos.
#
# Criada em 2005 por Chad Hurley, Jawed Karin e Steve Chen, que por curiosidade também eram fundadores do [Paypal](https://www.paypal.com/br/home). Tinham a ideia de criar uma ferramenta que fosse fácil de compartilhar os vídeos, já que os e-mails (ferramenta usada na época) eram complicados, pois havia um limite de tamanho do envio do vídeo, para assistir tinha que fazer o download (sua internet tinha que ser boa) e era complexo a distribuição (os e-mails iam para caixa de spam).
#
# Não precisa dizer que o YouTube cresceu rapidamente, chamando a atenção de grandes marcas, até o Google comprar a plataforma por US$ 1,65 bilhões.
#
# Hoje o YouTube conta com [2,56 bilhões](https://resultadosdigitais.com.br/marketing/redes-sociais-mais-usadas-no-brasil/#:~:text=O%20YouTube%20%C3%A9%20a%20principal,horas%20de%20v%C3%ADdeos%20visualizados%20diariamente.) de usuários ativos, o serviço é responsável por 20,4% do tráfego mundial de internet móvel, segundo a pesquisa da [The Mobile Internet Phenomena Report](https://www.sandvine.com/download-mobile-internet-phenomena-report-2021), realizada pela Sandvine.
#
# Vale lembrar que o mercado de streaming, é uma oportunidade a ser explorada pelos times de marketing, sendo que em 2020 movimentou [US 67 bilhões](https://www.statista.com/statistics/483096/svod-revenue-worldwide/) e se prevê que o mercado global poderá ultrapassar US 126 bilhões em receita até 2026.
#
# E por todos esses fatores é fundamental investir em técnicas para automatizar a coleta de dados dessa ferramenta, para que possa gerar inteligência de mercado e estratégica.

# %% [markdown]
# ## Porque automatizar a extração de dados

# %% [markdown]
# Para responder essa pergunta devemos entender se o seu canal é uma ferramenta de atração ou engajamento do seu público alvo dentro do seu [funil de marketing](https://blog.rdstation.com/funil-de-marketing/), pois se a resposta for NÃO, minha sugestão não é automatizar essa tarefa, já que dará trabalho e seus dados serão ineficazes para conectar as ações de campanhas. Acredito que o próprio dashboard do YouTube irá te suprir bem para esta necessidade específica.
#
# Se você faz campanhas de marketing ou conecta alguma ação de vendas e [customer experience (CX)](https://www.salesforce.com/br/atendimento-ao-cliente/customer-experience/) aos vídeos que você produz no YouTube. Essa automatização é importante para você.
#
# Imagine você ter que medir o desempenho de múltiplas campanhas.
#
# Exemplo: você usa seus vídeos no YouTube como [topo de funil](https://resultadosdigitais.com.br/marketing/conteudo-topo-de-funil/), para atrair novos clientes, impulsionando via [google ads](https://ads.google.com/), além de engajar os próprios seguidores atuais em canais como Facebook e LinkedIn. E ao final do vídeo ainda tem [call to action](https://resultadosdigitais.com.br/marketing/tudo-sobre-call-to-action/) que irá te levar para uma página de [captura de lead](https://www.moskitcrm.com/blog/ferramentas-geracao-de-leads), que será uma fonte de dados para o [CRM](https://www.salesforce.com/br/crm/) da sua empresa, para enfim você medir o volume de vendas.
#
# Como você irá medir qual das campanhas realmente foi a mais eficiente? Qual video converteu mais? Será que o vídeo que converteu menos, não foi o que trouxe mais vendas? E muitas outras perguntas. E não é lógico você ficar extraindo dados em planilhas toda vez ou deixar para terminar a campanha para ver qual foi o melhor. Você estará perdendo dinheiro.
#
# E isso foi o que me motivou a escrever esse artigo, quero mostrar como extrair os dados do YouTube utilizando a sua [API](https://www.techtudo.com.br/listas/2020/06/o-que-e-api-e-para-que-serve-cinco-perguntas-e-respostas.ghtml). Usaremos algumas técnicas com [Python](https://tecnoblog.net/responde/o-que-e-python-guia-para-iniciantes/), mas prometo que será bem simples de executar, é só seguir o passo a passo.

# %% [markdown]
# ## Documentação

# %% [markdown]
# O próprio YouTube desenvolveu a API, na qual permite a incorporação de funções executadas no próprio site do YouTube, possibilitando extrair dados.
#
# Para você que não sabe direito o que é uma API (Application Programming Interface), é uma interface que possibilita a comunicação (troca de informação) por uma série de padrões e protocolos. Isso nos permite desenvolver nossos próprios softwares e aplicativos que podem se conectar a outra ferramenta.
#
# Um exemplo é o Instagram, quando você posta um story e vai adicionar o restaurante onde você está, utilizando o arroba da localização, já aparece a opção da sua atual localização, pois ela se conectou com a API do Google Map ou algo similar e puxou os dados, para agilizar sua transcrição.
#
# Para seguirmos com o tema, vou deixar aqui a [Documentação da API do YouTube](https://developers.google.com/youtube/v3/docs?hl=pt-br), sugiro você ler e conhecer um pouco, pois irei tratar neste artigo de uma forma  sucinta, se quiser se aprofundar, buscar extrair alguma feature diferente, todas as respostas vão estar na documentação.
#
# O primeiro fato a se entender é que existem duas formas de se credenciar na API, para que o YouTube nos forneça o acesso.
#
# OAuth 2.0: um protocolo de autorização que permite que uma aplicação se autentique em outra, tornando muito segura.
# Chave de API: é um código que identifica o aplicativo ou o projeto que está fazendo uma chamada para a API. E é esse que iremos usar

# %% [markdown]
# ## Credenciamento Google API

# %% [markdown]
# Para ambas as opções de credenciamento é necessário acessar a plataforma do [Google API](https://console.cloud.google.com/apis/dashboard?pli=1). Se você não tem cadastro ainda, sugiro entrar e criar sua conta.
#
# Talvez você necessite aumentar sua cota de projetos no Google API. Para isso é só entrar no [formulário](https://support.google.com/code/contact/project_quota_increase) e responder honestamente todas as informações, dentro de 1 semana, vão te retornar com um parecer.
#
# O primeiro passo é ativar a [API do YouTube Data API v3](https://console.cloud.google.com/marketplace/product/google/youtube.googleapis.com). Você pode acessar o link ou fazer uma busca, no próprio buscador da Google API.
#
# <img alt="youtube data api" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/Captura-de-tela-2022-10-17-130710.png">
#
# Após ativar, você irá clicar no menu da esquerda, passar o mouse sobre a opção “APIs e serviços” e selecionar a opção “Credenciais”.
#
# <img alt="credenciamento 02" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/credencial01.png">
#
# OBS: Se você entrar e não estiver aparecendo nada, pode ser que você precise criar um “novo projeto”. É só clicar em “criar um projeto”, dar um nome, selecionar a organização (caso tenha) e “criar”. Logo em seguida já estará liberado todas as funções.
#
# Agora você está na página de credenciais, clique na opção "+CRIAR CREDENCIAIS”, e selecione a “chave de API”. Em alguns instantes ele vai criar para você a chave, mas se atente, você precisará configurá-lo, para isso é só clicar em “Edit API key”.
#
# <img alt="credenciamento 03" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/credencial02.png">
#
# Você irá configurar sua chave. Se quiser, mude o nome da chave, isso serve apenas para sua própria organização. Na opção “Restrição de aplicativo” deixe a opção "Nenhum" ativada.
#
# Na opção “Restrições da API”, você irá marcar a alternativa “restringir chave”, ao fazer isso, irá surgir uma caixa de seleção. Escolha a opção “YouTube Data API v3” e dê um “ok”. E por último clique em salvar.
#
# <img alt="credenciamento 04" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/credencial03.png">
#
# Após finalizar a etapa anterior, você vai ser jogado para a tela de credenciais. Clique em "Exibir Chave”. Irá aparecer um código alfanumérico,  salve isso, pois será importante para outro momento. Vale ressaltar que essa chave você não pode compartilhar com ninguém.
#
# <img alt="credenciamento 05" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/credencial04.png">

# %% [markdown]
# ## Primeiros passos

# %% [markdown]
# E o primeiro passo é importar as bibliotecas necessárias.

# %%
from IPython.display import YouTubeVideo
import pandas as pd
import numpy as np

# %% [markdown]
# Vamos ter que instalar o google-api-python-client, sendo um módulo das APIs do Google em Python cliente, que nos permite fazer essa consulta.

# %%
# !pip install --upgrade google-api-python-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.4 MB 5.8 MB/s
# ...
#   Attempting uninstall: google-auth-httplib2
#     Found existing installation: google-auth-httplib2 0.0.4
#     Uninstalling google-auth-httplib2-0.0.4:
#       Successfully uninstalled google-auth-httplib2-0.0.4
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 1.12.11
#     Uninstalling google-api-python-client-1.12.11:
#       Successfully uninstalled google-api-python-client-1.12.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# earthengine-api 0.1.327 requires google-api-python-client<2,>=1.12.1, but you have google-api-python-client 2.65.0 which is incompatible.
# ...

# %% [markdown]
# E em seguida adicionar a biblioteca “build”.

# %%
from googleapiclient.discovery import build

# %% [markdown]
# Esse é o momento que iremos utilizar aquela chave de credencial no Google API.

# %%
youTubeApiKey = "XXXXXXXXXXXXXXXXXXXXXXXXXXXX"

# %% [markdown]
# E para permitir fazer as consultas, usamos a função “build”, que exige as variáveis de qual ferramenta irá extrair (no caso, YouTube), a sua versão (v3) e por último a chave da API.

# %%
youtube = build('youtube','v3', developerKey=youTubeApiKey)

# %% [markdown]
# A Partir desse momento já estamos autorizados para fazer a extração de dados.

# %% [markdown]
# ## Extraindo os dados

# %% [markdown]
# Como estudo de caso, vamos tentar extrair os dados de uma playlist específica do meu canal, ou seja, todos os vídeos que estão dentro desta playlist.
#
# Para solicitar os dados da playlist, precisamos do identificador da playlist, ele é bem fácil de encontrar. Basta acessar a playlist que você deseja, você vai encontrar ela na URL, e vai estar dentro do parâmetro chamado list=, tudo após esse igual é o identificador da playlist.
#
# <img alt="credenciamento 05" width="50%" src="https://zeroai.com.br/wp-content/uploads/2022/10/cod01.png">
#
# Os próximos passo são criar as variáveis com o ID da playlist, o nome da playlist e o nextPage_token

# %%
playlistId = 'PLEkHCyHg-ngCUab9CPAsx3HrR3QRx9m-S'
playlistName = 'Tracker Talk'
nextPage_token = None

# %% [markdown]
# Para extrair os dados dos vídeos na playlist, criamos uma lista utilizando um  laço de repetição (while), ou seja, irá ficar reproduzindo o comando até não haver mais vídeos para ser extraído os dados.
#
# E para fazer isso acontecer, chamamos aquele objeto criado lá em cima “YouTube” e passamos a função [playlistItem](https://developers.google.com/youtube/v3/docs/playlistItems?hl=pt-br) (você pode entender ela melhor na documentação) e a [list](https://developers.google.com/youtube/v3/docs/playlistItems/list?hl=pt-br), na qual irá listar os recursos da playlist. E para isso será necessário passar os parâmetros:
#
# *   **part**: vamos usar o atributo snippet, pois irá puxar todas as propriedades
#
# *   **playlistId**: o id da playlist que coletamos
#
# *   **maxResults**: o máximo de resultados, no nosso exemplo iremos colocar 50 videos.
#
# *   **pageToken**: usaremos essa artimanha o nextPage_token (None), pois se a nossa playlist tiver mais de 50 vídeos, ele não irá puxar os dados. É por este fator que criamos um laço de repetição, que toda vez que encontrar o resultado irá atribuir à variável playlist, sendo necessário atualizar a variável nextpage_Token com a informação retornada da playlist e se esse token, que foi retornado pela consulta, for vazio, o laço de repetição irá parar.

# %%
playlist_videos = []
 
while True:
  res = youtube.playlistItems().list(part='snippet', playlistId = playlistId, maxResults=50, pageToken=nextPage_token).execute()
  playlist_videos += res['items']
  
  nextPage_token = res.get('nestPageToken')
 
  if nextPage_token is None:
    break

# %%
playlist_videos
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'LTFCKPopP4uIXR_0lcn1D40oWBQ',
#   'id': 'UExFa0hDeUhnLW5nQ1VhYjlDUEFzeDNIclIzUVJ4OW0tUy41NkI0NEY2RDEwNTU3Q0M2',
#   'snippet': {'publishedAt': '2020-04-01T17:54:47Z',
#    'channelId': 'UCAJpPXNTogSIQwmwQm55Uxw',
#    'title': 'Tracker Talk - CORONAVÍRUS e porque Comunidade & Liderança pode ser uma SAÍDA',
#    'description': 'Um bate papo aberto entre dois líderes de nossa comunidade para falar das ações que as comunidades podem realizar neste momento de crise.\n\n== Links da LabTrack ==\n- Facebook: https://www.facebook.com/labtrack\n- LinkedIn: http://linkedin.com/school/labtrackensino\n- Instagram: https://www.instagram.com/labtrackensino/\n- Comunidade no WhatsApp: http://bit.ly/labtrackcomunidade',
#    'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/ghOkow0MXnA/default.jpg',
#      'width': 120,
#      'height': 90},
#     'medium': {'url': 'https://i.ytimg.com/vi/ghOkow0MXnA/mqdefault.jpg',
#      'width': 320,
# ...

# %% [markdown]
# A consulta nos retorna um [.json](https://rockcontent.com/br/blog/json/), e os dados que queremos estão dentro da chave itens. Outra função que podemos fazer é ver quantos vídeos tem na playlist.

# %%
print("Número total de vídeos na Playlist ", len(playlist_videos))
# Out:
# Número total de vídeos na Playlist  30

# %% [markdown]
# No caso, confirmamos que há em nossa playlist 30 vídeos.
#
# Outra ação importante é coletar os ID de cada vídeo que está na playlist, que está dentro daquele json que nos retornou. Então vamos criar uma [função lambda](https://www.hashtagtreinamentos.com/funcoes-lambda-python#:~:text=O%20que%20s%C3%A3o%20express%C3%B5es%20Lambda,utiliz%C3%A1%2Dla%20dentro%20do%20c%C3%B3digo.) que irá filtrar as variáveis e armazená-la dentro de uma lista.

# %%
videos_ids = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))

# %%
videos_ids
# Out:
# ['ghOkow0MXnA',
#  'JU3cmPFFBcw',
#  'MrVcJPPeYJw',
#  'Mnf2Pcxn5xc',
#  '54Fx9kG7vhQ',
#  'PS2vhqYG6wQ',
#  'nQZdR0aO3Gw',
#  'GqNdJXS446U',
#  'GpBcZ6jhPX8',
#  'yTwaueEopwo',
#  'c7gmTJWdmOo',
#  '3yR_Wuy8zZ0',
#  '0-6-0eflIZM',
#  'mER2vptlKe0',
#  'S0ZpA_ONE4c',
#  'uyzeaeW7XSM',
#  'utBcmaoiwW0',
#  'Job_jrkbMHQ',
#  'w2dGPRmjpIs',
#  'x0AQ32yyrR0',
#  'Ok_lJ48T9Ic',
#  'PFusDt3GyD8',
#  'ljNqIeBdONg',
#  'OLVdraY-6c8',
#  'fnEJ_JjD1BQ',
#  'cdrav5KntYM',
#  'Z0SIZ1bBqVs',
#  'Ygzjmd6ckHc',
#  'jZ-FDOBgf1k',
#  'QT_5T7ZeU_I']

# %% [markdown]
# Vou usar essa lista de IDs para fazer uma consulta de endpoint de [vídeos](https://developers.google.com/youtube/v3/docs/videos?hl=pt-br) da nossa API. Para isso vamos criar uma nova lista chamada stats, na qual ficará armazenado as informações.
#
# Para criar a lista, vamos usar o laço de repetição, que para cada consulta iremos extrair os dados estatísticos dos vídeos.

# %%
stats = []
 
for video_id in videos_ids:
  res = youtube.videos().list(part='statistics', id=video_id).execute()
  stats += res['items']

# %%
stats
# Out:
# [{'kind': 'youtube#video',
#   'etag': 'qNNBN4iM1gYSmaknwg3Q1nSREl0',
#   'id': 'ghOkow0MXnA',
#   'statistics': {'viewCount': '67',
#    'likeCount': '0',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': '3TocwpZQFkr-UJJKE-6ch0GSclw',
#   'id': 'JU3cmPFFBcw',
#   'statistics': {'viewCount': '100',
#    'likeCount': '5',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'TD_1BCBQqPE3d6fXAgjWyN5d3nE',
#   'id': 'MrVcJPPeYJw',
#   'statistics': {'viewCount': '92',
#    'likeCount': '9',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'm7zhIJmThdfLc3stBVqcwwgViDc',
#   'id': 'Mnf2Pcxn5xc',
#   'statistics': {'viewCount': '34',
#    'likeCount': '1',
#    'favoriteCount': '0',
#    'commentCount': '0'}},
#  {'kind': 'youtube#video',
#   'etag': 'R6SxXtDSmu8oeF292SMvFHwTl2I',
#   'id': '54Fx9kG7vhQ',
#   'statistics': {'viewCount': '107',
# ...

# %% [markdown]
# Já chegamos a um ponto ótimo, mas para fazer uma análise de dados profunda, não é interessante para mim, os dados estarem nessa estrutura. E é por isso que iremos transformá-lo em um dataframe, sendo mais performático.
#
# E para fazer isso, usaremos o mesmo recurso que usamos, a função lambda, mas neste caso queremos extrair os dados de título da playlist, URL, data de publicação do vídeo, descrição, ID do vídeo, número de likes, comentários e visualizações.

# %%
videos_title = list(map(lambda x: x['snippet']['title'], playlist_videos))
url_thumbnails = list(map(lambda x: x['snippet']['thumbnails']['high']['url'], playlist_videos))
published_date = list(map(lambda x: str(x['snippet']['publishedAt']), playlist_videos)) #conversion from ISO8601 date format
video_description = list(map(lambda x: x['snippet']['description'], playlist_videos))
videoid = list(map(lambda x: x['snippet']['resourceId']['videoId'], playlist_videos))
liked = list(map(lambda x: int(x['statistics']['likeCount']), stats))
views = list(map(lambda x: int(x['statistics']['viewCount']), stats))
comment = list(map(lambda x: int(x['statistics']['commentCount']), stats))

# %% [markdown]
# Não podemos esquecer da informação de quando esses dados foram extraídos, para saber se estão atualizados. Para isso usamos uma biblioteca chamada datatime.

# %%
from datetime import datetime 
 
extraction_date = [str(datetime.now())]*len(videos_ids)

# %% [markdown]
# Já temos todas as informações para criar o dataframe, vamos utilizar um dicionário com uma chave para cada lista criada.

# %%
playlist_df = pd.DataFrame({'title':videos_title,
      'video_id':videoid,
      'video_description':video_description,
      'published_date':published_date,
      'extraction_date':extraction_date,
      'likes':liked,
      'views':views,
      'comment':comment,
      'thumbnail': url_thumbnails})
playlist_df.head()
# Out:
#                                                title     video_id  \
# 0  Tracker Talk - CORONAVÍRUS e porque Comunidade...  ghOkow0MXnA
# 1  Tracker Talk - Como a LGPD impacta a Análise d...  JU3cmPFFBcw
# 2  Tracker Talk - A cultura DevOps como oportunid...  MrVcJPPeYJw
# 3  Tracker Talk - Vendas na quarentena, o que fazer?  Mnf2Pcxn5xc
# 4  Tracker Talk - A importância do Design no dese...  54Fx9kG7vhQ
#
#                                    video_description        published_date  \
# 0  Um bate papo aberto entre dois líderes de noss...  2020-04-01T17:54:47Z
# 1  Um bate papo com os mentores da LabTrack espec...  2020-04-08T01:13:33Z
# 2  Um bate papo com o Jefferson Machado, analista...  2020-04-08T01:13:56Z
# 3  Um bate papo com o mentor da LabTrack Fernando...  2020-04-15T01:20:06Z
# 4  Um bate papo com os mentores da LabTrack, Gari...  2020-04-16T01:32:56Z
#
#               extraction_date  likes  views  comment  \
# 0  2022-10-19 12:24:31.847419      0     67        0
# ...

# %% [markdown]
# A partir desse momento é fazer um tratamento e análise de dados, técnica que você poderá ver em outros artigos como [Explorando dados do Airbnb](https://zeroai.com.br/2021/11/01/dados-airbnb/), e assim encontrar padrões e gerar inteligência de mercado.

# %% [markdown]
# ## Resumo final

# %% [markdown]
# Pode parecer um pouco complexo, mas após criado a aplicação é só automatizar, e os dados já irão sair prontos. Claro que você pode puxar nesse momento dados de outros dataframes ou jogar para uma ferramenta de BI. Vai da sua estratégia de análise.
#
# Volto a invocar aqui a sua reflexão ao estudo da documentação da API do YouTube, pois ainda há muitos outros dados e recursos a serem extraídos.
#
# *   Produção [Zero.AI](zeroai.com.br)
#
# *   Texto e pesquisa [Hyan Dias](https://www.linkedin.com/in/hyan-dias/)
#
# *   Revisão
#
# *   Ilustração e animação [Hyan Dias](https://www.linkedin.com/in/hyan-dias/)
#
# *   Fonte de inspiração [Programação Dinâmica](https://www.youtube.com/watch?v=olDCJ1w3FLM&list=LL&index=1&t=230s)
